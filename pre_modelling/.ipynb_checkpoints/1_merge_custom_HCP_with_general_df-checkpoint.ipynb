# %%
import pandas as pd

# %%
df_total = pd.read_feather(r'F:\Projects\Pfizer_mCRPC\Data\Raw_data\02_total_with_datediff.feather')
df_HCP = pd.read_csv(r'F:\Projects\Pfizer_mCRPC\Data\Raw_data\03_Pfizer_mCRPC_HCPHCOS_WITH_DUMMIES.csv')

# %%
df_HCP.head()
# Out:
#    patient_id  hcos_mcrpc_decile  hcp_zx_decile  hcp_mcrpc_decile  \
# 0   839544914               10.0           10.0                10
# 1   582866916                NaN            NaN                 7
# 2   171011889               10.0            NaN                 3
# 3   645101969                4.0            1.0                 3
# 4   152961559                7.0            1.0                 5
#
#    hcp_agonist_pat_cnt  hcp_antagonist_pat_cnt  hcp_adt_score       hhi  \
# 0                 61.0                    20.0       0.506173  0.528096
# 1                  6.0                     NaN       1.000000  0.781250
# 2                  1.0                     NaN       1.000000  1.000000
# 3                  NaN                     NaN            NaN  1.000000
# 4                  1.0                     NaN       1.000000  0.520000
#
#    pri_spcl_desc_abdominal_radiology  pri_spcl_desc_abdominal_surgery  \
# ...

# %%
df_total_with_dummies = df_total.merge(df_HCP, on = 'patient_id', how='inner')

# %%
df_total_with_dummies.head()
# Out:
#    patient_id  pn_flag  age_index  age_pc  c00142_claim_cnt  c00142_flag  \
# 0   377317624        0         85      85                 0            0
# 1    73066609        0         80      78                 0            0
# 2    70175556        0         50      50                 0            0
# 3   713474282        0         83      81                 0            0
# 4  1563563420        0         70      64                 0            0
#
#    c00142_index_max_dd  c00142_index_min_dd  c00142_max_min_dd  \
# 0                  NaN                  NaN                NaN
# 1                  NaN                  NaN                NaN
# 2                  NaN                  NaN                NaN
# 3                  NaN                  NaN                NaN
# 4                  NaN                  NaN                NaN
#
#    c00740_claim_cnt       ...         \
# 0                 0       ...
# 1                 0       ...
# 2                 0       ...
# ...

# %%
df_total_with_dummies.to_feather(r'F:\Projects\Pfizer_mCRPC\Data\Raw_data\04_total_with_datediff_and_dummies.feather')
df_total_with_dummies.to_csv(r'F:\Projects\Pfizer_mCRPC\Data\Raw_data\04_total_with_datediff_and_dummies.csv', index=False)

# %%
df_total_with_dummies.head()
# Out:
#    patient_id  pn_flag  age_index  age_pc  c00142_claim_cnt  c00142_flag  \
# 0   377317624        0         85      85                 0            0
# 1    73066609        0         80      78                 0            0
# 2    70175556        0         50      50                 0            0
# 3   713474282        0         83      81                 0            0
# 4  1563563420        0         70      64                 0            0
#
#    c00142_index_max_dd  c00142_index_min_dd  c00142_max_min_dd  \
# 0                  NaN                  NaN                NaN
# 1                  NaN                  NaN                NaN
# 2                  NaN                  NaN                NaN
# 3                  NaN                  NaN                NaN
# 4                  NaN                  NaN                NaN
#
#    c00740_claim_cnt       ...         \
# 0                 0       ...
# 1                 0       ...
# 2                 0       ...
# ...

# %%
# Due to the repull one feature is set to 0, columns related should be deleted
ls_deleted_features = ['g214060_claim_cnt', 'g214060_flag', 'g214060_max_min_dd', 'g214060_index_max_dd', 'g214060_index_min_dd']
df_total_with_dummies.drop(ls_deleted_features, axis=1, inplace=True)

# %%
df_total_with_dummies.to_feather(r'F:\Projects\Pfizer_mCRPC\Data\Raw_data\04_total_with_datediff_and_dummies.feather')
df_total_with_dummies.to_csv(r'F:\Projects\Pfizer_mCRPC\Data\Raw_data\04_total_with_datediff_and_dummies.csv', index=False)

# %% [markdown]
# ## Make version without flags

# %%
df_total_with_dummies = pd.read_feather(r'F:\Projects\Pfizer_mCRPC\Data\Raw_data\04_total_with_datediff_and_dummies.feather')

# %%
flag_columns = [colname for colname in df_total_with_dummies.columns if (colname[-4:] == 'flag') and not (colname == 'pn_flag')]

# %%
df_no_flags = df_total_with_dummies.drop(columns = flag_columns)

# %%
df_no_flags.to_feather(r'F:\Projects\Pfizer_mCRPC\Data\Raw_data\04_total_with_datediff_and_dummies_no_flags.feather')
