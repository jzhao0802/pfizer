# %%
import pandas as pd

# %%
df = pd.read_excel(r'F:\Projects\Pfizer_mCRPC\Data\Raw_data\Pfizer_mCRPC_ONCEMR.xlsx')

# %%
df.head()
# Out:
#    PATIENT_ID INDEX_DATE ONC_LATEST_STAGE ONC_LATEST_STAGE_DATE  MET_DATE1  \
# 0   579090634 2015-08-19         Stage IV            2011-01-01 2015-08-19
# 1  1769925066 2014-02-05         Stage IV            2015-05-01 2014-02-05
# 2   351771076 2015-01-22         Stage IV            2013-04-17 2015-01-22
# 3   127438607 2016-10-27         Stage IV            2008-01-01 2016-10-27
# 4   529344072 2015-07-31         Stage IV            2015-06-01 2015-07-31
#
#                     METAC_SITE_NM1  MET_DATE2 METAC_SITE_NM2 MET_DATE3  \
# 0                     OTHER CANCER        NaT            NaN       NaT
# 1  BONE & CONNECTIVE TISSUE CANCER        NaT            NaN       NaT
# 2  BONE & CONNECTIVE TISSUE CANCER 2015-02-05   OTHER CANCER       NaT
# 3                     OTHER CANCER        NaT            NaN       NaT
# 4  BONE & CONNECTIVE TISSUE CANCER 2017-04-25   OTHER CANCER       NaT
#
#   METAC_SITE_NM3   ...   ONC_TNM_DATE ONC_LATEST_T ONC_LATEST_T_DATE  \
# ...

# %%
df.dtypes
# Out:
# PATIENT_ID                          int64
# INDEX_DATE                 datetime64[ns]
# ONC_LATEST_STAGE                   object
# ONC_LATEST_STAGE_DATE      datetime64[ns]
# MET_DATE1                  datetime64[ns]
# METAC_SITE_NM1                     object
# MET_DATE2                  datetime64[ns]
# METAC_SITE_NM2                     object
# MET_DATE3                  datetime64[ns]
# METAC_SITE_NM3                     object
# MET_DATE4                  datetime64[ns]
# METAC_SITE_NM4                     object
# MET_DATE5                  datetime64[ns]
# METAC_SITE_NM5                     object
# MET_DATE6                  datetime64[ns]
# METAC_SITE_NM6                     object
# MET_DATE7                  datetime64[ns]
# METAC_SITE_NM7                     object
# ONC_PSA1                          float64
# ONC_PSA_DATE1              datetime64[ns]
# ONC_PSA2                          float64
# ONC_PSA_DATE2              datetime64[ns]
# ...
